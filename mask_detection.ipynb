# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 15577, done.
# remote: Counting objects: 100% (184/184), done.
# remote: Compressing objects: 100% (133/133), done.
# remote: Total 15577 (delta 79), reused 103 (delta 51), pack-reused 15393
# Receiving objects: 100% (15577/15577), 14.64 MiB | 18.22 MiB/s, done.
# Resolving deltas: 100% (10607/10607), done.

# %%
# %cd yolov5
# Out:
# /content/yolov5

# %%
# !pip install -r requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 kB 3.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 8.8 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip '/content/drive/My Drive/mask_detection.zip' -d '/content/drive/My Drive/Destination/'
# Out:
# Archive:  /content/drive/My Drive/mask_detection.zip
#   inflating: /content/drive/My Drive/Destination/mask_detection/config_mask_detect.yaml
#   inflating: /content/drive/My Drive/Destination/mask_detection/data_prepare
#    creating: /content/drive/My Drive/Destination/mask_detection/datasets/
#    creating: /content/drive/My Drive/Destination/mask_detection/datasets/mask/
#    creating: /content/drive/My Drive/Destination/mask_detection/datasets/mask/processed_annotations/
#    creating: /content/drive/My Drive/Destination/mask_detection/datasets/mask/train/
#    creating: /content/drive/My Drive/Destination/mask_detection/datasets/mask/train/images/
#   inflating: /content/drive/My Drive/Destination/mask_detection/datasets/mask/train/images/maksssksksss0.png
#   inflating: /content/drive/My Drive/Destination/mask_detection/datasets/mask/train/images/maksssksksss1.png
#   inflating: /content/drive/My Drive/Destination/mask_detection/datasets/mask/train/images/maksssksksss10.png
# ...

# %%
# %cd /content/drive/My Drive/Destination/mask_detection
# Out:
# [Errno 2] No such file or directory: '/content/drive/My Drive/Destination/mask_detection'
# /content/yolov5

# %%
# !ls
# Out:
# benchmarks.py	 data	     LICENSE	      requirements.txt	tutorial.ipynb
# CITATION.cff	 detect.py   models	      segment		utils
# classify	 export.py   README.md	      setup.cfg		val.py
# CONTRIBUTING.md  hubconf.py  README.zh-CN.md  train.py

# %%
# %cd /content/yolov5
# Out:
# /content/yolov5

# %%
# !python train.py --img 640 --batch 16 --epochs 100 --data /content/drive/MyDrive/Destination/mask_detection/config_mask_detect.yaml --weights yolov5s.pt --workers 0 --freez 10
# Out:
# train: weights=yolov5s.pt, cfg=, data=/content/drive/MyDrive/Destination/mask_detection/config_mask_detect.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=100, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=0, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[10], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# requirements: /content/requirements.txt not found, check failed.
# YOLOv5 🚀 v7.0-150-gbe61a64 Python-3.9.16 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# ...

# %%
# !python detect.py --source /content/drive/MyDrive/Destination/mask_detection/datasets/mask/valid/images/test.png --weights runs/train/exp2/weights/best.pt --conf 0.2
# Out:
# detect: weights=['runs/train/exp2/weights/best.pt'], source=/content/drive/MyDrive/Destination/mask_detection/datasets/mask/valid/images/test.png, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.2, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=1, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# requirements: /content/requirements.txt not found, check failed.
# YOLOv5 🚀 v7.0-150-gbe61a64 Python-3.9.16 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content/drive/MyDrive/Destination/mask_detection/datasets/mask/valid/images/test.png: 448x640 6 without_masks, 38.5ms
# ...

# %%
# !python val.py --data /content/drive/MyDrive/Destination/mask_detection/config_mask_detect.yaml --weights runs/train/exp2/weights/best_150.pt
# Out:
# val: data=/content/drive/MyDrive/Destination/mask_detection/config_mask_detect.yaml, weights=['runs/train/exp2/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.6, max_det=300, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False, dnn=False
# requirements: /content/requirements.txt not found, check failed.
# YOLOv5 🚀 v7.0-150-gbe61a64 Python-3.9.16 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# val: Scanning /content/drive/MyDrive/Destination/mask_detection/datasets/mask/valid/labels... 171 images, 1 backgrounds, 0 corrupt: 100% 172/172 [00:00<00:00, 192.63it/s]
# val: New cache created: /content/drive/MyDrive/Destination/mask_detection/datasets/mask/valid/labels.cache
# ...
